# %%
import os
import nltk
import nltk.corpus

# %%
print(os.listdir(nltk.data.find("corpora")))
# Out:
# ['abc', 'abc.zip', 'alpino', 'alpino.zip', 'bcp47.zip', 'biocreative_ppi', 'biocreative_ppi.zip', 'brown', 'brown.zip', 'brown_tei', 'brown_tei.zip', 'cess_cat', 'cess_cat.zip', 'cess_esp', 'cess_esp.zip', 'chat80', 'chat80.zip', 'city_database', 'city_database.zip', 'cmudict', 'cmudict.zip', 'comparative_sentences', 'comparative_sentences.zip', 'comtrans.zip', 'conll2000', 'conll2000.zip', 'conll2002', 'conll2002.zip', 'conll2007.zip', 'crubadan', 'crubadan.zip', 'dependency_treebank', 'dependency_treebank.zip', 'dolch', 'dolch.zip', 'europarl_raw', 'europarl_raw.zip', 'extended_omw.zip', 'floresta', 'floresta.zip', 'framenet_v15', 'framenet_v15.zip', 'framenet_v17', 'framenet_v17.zip', 'gazetteers', 'gazetteers.zip', 'genesis', 'genesis.zip', 'gutenberg', 'gutenberg.zip', 'ieer', 'ieer.zip', 'inaugural', 'inaugural.zip', 'indian', 'indian.zip', 'jeita.zip', 'kimmo', 'kimmo.zip', 'knbc.zip', 'lin_thesaurus', 'lin_thesaurus.zip', 'machado.zip', 'mac_morpho', 'mac_morpho.zip', 'masc_t
# ...

# %%
with open(r'C:\Users\LENOVO\Downloads\assignment\assignment\6.csv')as myfile:
    data=myfile.read().replace('\n','')

# %%
data2 = data.replace("/","")

# %%
for i, line in enumerate(data2.split('\n')):
    if i>10:
        break
    print(str(i) + '+:\t' + line)
# Out:
# 0+:	text,relevance_x,count,relevance_y,dbpedia_resourceItalian wedding cookies,0.856126,1.0,,cookies year-round,0.649284,1.0,,Christmas cookie recipes,0.640123,1.0,,pure vanilla extract,0.625617,1.0,,final product,0.618375,1.0,,butterâ€™s consistency,0.61536,1.0,,Italian Christmas cookies,0.613213,1.0,,Italian fig cookies,0.572101,1.0,,full prep,0.566289,1.0,,very little kid,0.550495,1.0,,solution of vanilla bean extract,0.548505,1.0,,Vanilla,0.545127,1.0,0.995779,http:dbpedia.orgresourceVanillafamily tradition,0.543097,1.0,,lot of Christmas cookies,0.536722,1.0,,Italian wedding cookies recipe,0.535288,2.0,,vanilla extract,0.534037,1.0,,almond,0.532914,1.0,,perfectly balanced almond flavor,0.527936,1.0,,final baking stretch,0.526526,1.0,,lot,0.525377,1.0,,cold temps mixes,0.522587,1.0,,Nonnaâ€™s recipes,0.520602,1.0,,amaretti cookies,0.519783,1.0,,Ziploc bag,0.519341,1.0,,Tender,0.519008,1.0,,ingredients,0.518537,2.0,,front of the fireplace,0.517419,1.0,,trays,0.516676,1.0,,Almonds,0
# ...

# %%
from nltk import sent_tokenize,word_tokenize

# %%
sent_tokenize(data2)
# Out:
# ['text,relevance_x,count,relevance_y,dbpedia_resourceItalian wedding cookies,0.856126,1.0,,cookies year-round,0.649284,1.0,,Christmas cookie recipes,0.640123,1.0,,pure vanilla extract,0.625617,1.0,,final product,0.618375,1.0,,butterâ€™s consistency,0.61536,1.0,,Italian Christmas cookies,0.613213,1.0,,Italian fig cookies,0.572101,1.0,,full prep,0.566289,1.0,,very little kid,0.550495,1.0,,solution of vanilla bean extract,0.548505,1.0,,Vanilla,0.545127,1.0,0.995779,http:dbpedia.orgresourceVanillafamily tradition,0.543097,1.0,,lot of Christmas cookies,0.536722,1.0,,Italian wedding cookies recipe,0.535288,2.0,,vanilla extract,0.534037,1.0,,almond,0.532914,1.0,,perfectly balanced almond flavor,0.527936,1.0,,final baking stretch,0.526526,1.0,,lot,0.525377,1.0,,cold temps mixes,0.522587,1.0,,Nonnaâ€™s recipes,0.520602,1.0,,amaretti cookies,0.519783,1.0,,Ziploc bag,0.519341,1.0,,Tender,0.519008,1.0,,ingredients,0.518537,2.0,,front of the fireplace,0.517419,1.0,,trays,0.516676,1.0,,Almonds,0.5
# ...

# %%
for sent in sent_tokenize(data2):
    print(word_tokenize(sent))
# Out:
# ['text', ',', 'relevance_x', ',', 'count', ',', 'relevance_y', ',', 'dbpedia_resourceItalian', 'wedding', 'cookies,0.856126,1.0', ',', ',cookies', 'year-round,0.649284,1.0', ',', ',Christmas', 'cookie', 'recipes,0.640123,1.0', ',', ',pure', 'vanilla', 'extract,0.625617,1.0', ',', ',final', 'product,0.618375,1.0', ',', ',butterâ€™s', 'consistency,0.61536,1.0', ',', ',Italian', 'Christmas', 'cookies,0.613213,1.0', ',', ',Italian', 'fig', 'cookies,0.572101,1.0', ',', ',full', 'prep,0.566289,1.0', ',', ',very', 'little', 'kid,0.550495,1.0', ',', ',solution', 'of', 'vanilla', 'bean', 'extract,0.548505,1.0', ',', ',Vanilla,0.545127,1.0,0.995779', ',', 'http', ':', 'dbpedia.orgresourceVanillafamily', 'tradition,0.543097,1.0', ',', ',lot', 'of', 'Christmas', 'cookies,0.536722,1.0', ',', ',Italian', 'wedding', 'cookies', 'recipe,0.535288,2.0', ',', ',vanilla', 'extract,0.534037,1.0', ',', ',almond,0.532914,1.0', ',', ',perfectly', 'balanced', 'almond', 'flavor,0.527936,1.0', ',', ',final', 'b
# ...

# %%
from nltk.corpus import stopwords
stopwords_en =stopwords.words('english')

# %%
single_tokenized_lowered = list(map(str.lower,word_tokenize(data2)))
print(single_tokenized_lowered)
# Out:
# ['text', ',', 'relevance_x', ',', 'count', ',', 'relevance_y', ',', 'dbpedia_resourceitalian', 'wedding', 'cookies,0.856126,1.0', ',', ',cookies', 'year-round,0.649284,1.0', ',', ',christmas', 'cookie', 'recipes,0.640123,1.0', ',', ',pure', 'vanilla', 'extract,0.625617,1.0', ',', ',final', 'product,0.618375,1.0', ',', ',butterâ€™s', 'consistency,0.61536,1.0', ',', ',italian', 'christmas', 'cookies,0.613213,1.0', ',', ',italian', 'fig', 'cookies,0.572101,1.0', ',', ',full', 'prep,0.566289,1.0', ',', ',very', 'little', 'kid,0.550495,1.0', ',', ',solution', 'of', 'vanilla', 'bean', 'extract,0.548505,1.0', ',', ',vanilla,0.545127,1.0,0.995779', ',', 'http', ':', 'dbpedia.orgresourcevanillafamily', 'tradition,0.543097,1.0', ',', ',lot', 'of', 'christmas', 'cookies,0.536722,1.0', ',', ',italian', 'wedding', 'cookies', 'recipe,0.535288,2.0', ',', ',vanilla', 'extract,0.534037,1.0', ',', ',almond,0.532914,1.0', ',', ',perfectly', 'balanced', 'almond', 'flavor,0.527936,1.0', ',', ',final', 'b
# ...

# %%
stopwords_en = set(stopwords.words('english'))
print([word for word in single_tokenize_lowered if word not in stopwords_en])
# Out:
# ['text', ',', 'relevance_x', ',', 'count', ',', 'relevance_y', ',', 'dbpedia_resourceitalian', 'wedding', 'cookies,0.856126,1.0', ',', ',cookies', 'year-round,0.649284,1.0', ',', ',christmas', 'cookie', 'recipes,0.640123,1.0', ',', ',pure', 'vanilla', 'extract,0.625617,1.0', ',', ',final', 'product,0.618375,1.0', ',', ',butterâ€™s', 'consistency,0.61536,1.0', ',', ',italian', 'christmas', 'cookies,0.613213,1.0', ',', ',italian', 'fig', 'cookies,0.572101,1.0', ',', ',full', 'prep,0.566289,1.0', ',', ',very', 'little', 'kid,0.550495,1.0', ',', ',solution', 'vanilla', 'bean', 'extract,0.548505,1.0', ',', ',vanilla,0.545127,1.0,0.995779', ',', 'http', ':', 'dbpedia.orgresourcevanillafamily', 'tradition,0.543097,1.0', ',', ',lot', 'christmas', 'cookies,0.536722,1.0', ',', ',italian', 'wedding', 'cookies', 'recipe,0.535288,2.0', ',', ',vanilla', 'extract,0.534037,1.0', ',', ',almond,0.532914,1.0', ',', ',perfectly', 'balanced', 'almond', 'flavor,0.527936,1.0', ',', ',final', 'baking', 'str
# ...

# %%
from string import punctuation
print('from string.punctuation:',type(punctuation),punctuation)
# Out:
# from string.punctuation: <class 'str'> !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
stopwords_en_withpunct = stopwords_en.union(set(punctuation))
print(stopwords_en_withpunct)
# Out:
# {'whom', "you've", 'other', 'most', 'his', 'because', 'been', 'then', "shouldn't", 'doing', 'yourself', "wouldn't", '`', 'that', 'them', 'had', 'and', 'if', 'your', 'is', 'are', 'only', 'here', 'very', 're', ':', ')', '_', "needn't", 'him', 'against', 'from', 'not', '}', '+', 'do', 'have', 'ours', 'ain', '/', "doesn't", '$', '(', 'themselves', 'what', 'has', 'yourselves', "she's", 's', 'haven', '!', 'this', 'does', 'y', 'theirs', '*', 'of', 'now', 'hasn', 'they', 'she', 'each', 'needn', '~', 'by', 'in', 'on', 'out', '@', 'as', 'why', 'our', 'their', 'herself', "hasn't", 'me', 'about', "should've", 'ma', "it's", 'at', 'shan', 'so', 'between', 'having', 'shouldn', 'after', 'over', 'doesn', '-', 'ourselves', 'all', 'aren', "didn't", '^', 'hadn', '[', 'wouldn', 'further', "weren't", 'am', 'too', 'during', 'some', 'such', 'being', '&', 'with', 'up', '#', 'himself', 'her', "mightn't", 'yours', "isn't", 'no', 'should', ']', 'couldn', 'o', 'it', 'itself', 'an', '<', ';', 'who', 'for', 'didn'
# ...

# %%
print([word for word in single_tokenize_lowered if word not in stopwords_en_withpunct])
# Out:
# ['text', 'relevance_x', 'count', 'relevance_y', 'dbpedia_resourceitalian', 'wedding', 'cookies,0.856126,1.0', ',cookies', 'year-round,0.649284,1.0', ',christmas', 'cookie', 'recipes,0.640123,1.0', ',pure', 'vanilla', 'extract,0.625617,1.0', ',final', 'product,0.618375,1.0', ',butterâ€™s', 'consistency,0.61536,1.0', ',italian', 'christmas', 'cookies,0.613213,1.0', ',italian', 'fig', 'cookies,0.572101,1.0', ',full', 'prep,0.566289,1.0', ',very', 'little', 'kid,0.550495,1.0', ',solution', 'vanilla', 'bean', 'extract,0.548505,1.0', ',vanilla,0.545127,1.0,0.995779', 'http', 'dbpedia.orgresourcevanillafamily', 'tradition,0.543097,1.0', ',lot', 'christmas', 'cookies,0.536722,1.0', ',italian', 'wedding', 'cookies', 'recipe,0.535288,2.0', ',vanilla', 'extract,0.534037,1.0', ',almond,0.532914,1.0', ',perfectly', 'balanced', 'almond', 'flavor,0.527936,1.0', ',final', 'baking', 'stretch,0.526526,1.0', ',lot,0.525377,1.0', ',cold', 'temps', 'mixes,0.522587,1.0', ',nonnaâ€™s', 'recipes,0.520602,1.
# ...

# %%
from nltk.stem import PorterStemmer
porter = PorterStemmer()

for word in single_tokenize_lowered:
    print(porter.stem(word))
# Out:
# text
# ,
# relevance_x
# ,
# count
# ,
# relevance_i
# ,
# dbpedia_resourceitalian
# wed
# cookies,0.856126,1.0
# ,
# ,cooki
# year-round,0.649284,1.0
# ,
# ,christma
# cooki
# recipes,0.640123,1.0
# ,
# ,pure
# vanilla
# extract,0.625617,1.0
# ,
# ,final
# product,0.618375,1.0
# ,
# ,butterâ€™
# consistency,0.61536,1.0
# ,
# ,italian
# christma
# cookies,0.613213,1.0
# ,
# ,italian
# fig
# cookies,0.572101,1.0
# ,
# ,full
# prep,0.566289,1.0
# ,
# ,veri
# littl
# kid,0.550495,1.0
# ,
# ,solut
# of
# vanilla
# bean
# extract,0.548505,1.0
# ,
# ,vanilla,0.545127,1.0,0.995779
# ,
# http
# :
# dbpedia.orgresourcevanillafamili
# tradition,0.543097,1.0
# ,
# ,lot
# of
# christma
# cookies,0.536722,1.0
# ,
# ,italian
# wed
# cooki
# recipe,0.535288,2.0
# ,
# ,vanilla
# extract,0.534037,1.0
# ,
# ,almond,0.532914,1.0
# ,
# ,perfectli
# balanc
# almond
# flavor,0.527936,1.0
# ,
# ,final
# bake
# stretch,0.526526,1.0
# ,
# ,lot,0.525377,1.0
# ,
# ,cold
# temp
# mixes,0.522587,1.0
# ,
# ...

# %%
from nltk.stem import WordNetLemmatizer
wnl = WordNetLemmatizer()

# %%
for word in single_tokenized_lowered:
    print(wnl.lemmatize(word))
# Out:
# text
# ,
# relevance_x
# ,
# count
# ,
# relevance_y
# ,
# dbpedia_resourceitalian
# wedding
# cookies,0.856126,1.0
# ,
# ,cookies
# year-round,0.649284,1.0
# ,
# ,christmas
# cookie
# recipes,0.640123,1.0
# ,
# ,pure
# vanilla
# extract,0.625617,1.0
# ,
# ,final
# product,0.618375,1.0
# ,
# ,butterâ€™s
# consistency,0.61536,1.0
# ,
# ,italian
# christmas
# cookies,0.613213,1.0
# ,
# ,italian
# fig
# cookies,0.572101,1.0
# ,
# ,full
# prep,0.566289,1.0
# ,
# ,very
# little
# kid,0.550495,1.0
# ,
# ,solution
# of
# vanilla
# bean
# extract,0.548505,1.0
# ,
# ,vanilla,0.545127,1.0,0.995779
# ,
# http
# :
# dbpedia.orgresourcevanillafamily
# tradition,0.543097,1.0
# ,
# ,lot
# of
# christmas
# cookies,0.536722,1.0
# ,
# ,italian
# wedding
# cooky
# recipe,0.535288,2.0
# ,
# ,vanilla
# extract,0.534037,1.0
# ,
# ,almond,0.532914,1.0
# ,
# ,perfectly
# balanced
# almond
# flavor,0.527936,1.0
# ,
# ,final
# baking
# stretch,0.526526,1.0
# ,
# ,lot,0.525377,1.0
# ,
# ,cold
# temp
# ...

# %%
stop_words = set(stopwords.words('english'))
tokenized = sent_tokenize(data2)
for i in tokenized:
    wordlist = nltk.word_tokenize(i)
    wordlist = [w for w in wordlist if not w in stop_words]
    tagged =nltk.pos_tag(wordlist)
    
    print(tagged)
# Out:
# [('text', 'NN'), (',', ','), ('relevance_x', 'NN'), (',', ','), ('count', 'NN'), (',', ','), ('relevance_y', 'NN'), (',', ','), ('dbpedia_resourceItalian', 'JJ'), ('wedding', 'NN'), ('cookies,0.856126,1.0', 'NN'), (',', ','), (',cookies', 'VBZ'), ('year-round,0.649284,1.0', 'NN'), (',', ','), (',Christmas', 'NNP'), ('cookie', 'NN'), ('recipes,0.640123,1.0', 'NN'), (',', ','), (',pure', 'NN'), ('vanilla', 'NN'), ('extract,0.625617,1.0', 'NN'), (',', ','), (',final', 'JJ'), ('product,0.618375,1.0', 'NN'), (',', ','), (',butterâ€™s', 'NNP'), ('consistency,0.61536,1.0', 'NN'), (',', ','), (',Italian', 'JJ'), ('Christmas', 'NNP'), ('cookies,0.613213,1.0', 'NN'), (',', ','), (',Italian', 'JJ'), ('fig', 'NN'), ('cookies,0.572101,1.0', 'NN'), (',', ','), (',full', 'NNP'), ('prep,0.566289,1.0', 'NN'), (',', ','), (',very', 'RB'), ('little', 'JJ'), ('kid,0.550495,1.0', 'NN'), (',', ','), (',solution', 'NN'), ('vanilla', 'NN'), ('bean', 'NN'), ('extract,0.548505,1.0', 'NN'), (',', ','), (',Vani
# ...

# %%
sentences = nltk.sent_tokenize(data2)
tokenized_sentences = [nltk.word_tokenize(sentence)for sentence in sentences]
tagged_sentences = [nltk.pos_tag(sentence) for sentence in tokenized_sentences]
chunked_sentences = nltk.ne_chunk_sents(tagged_sentences, binary=True)

def extract_entity_names(t):
    entity_names = []
    
    if hasattr(t,'label') and t.label:
        if t.label() == 'NE':
            entity_names.append(' '.join([child[0] for child in t]))
        else:
            for child in t:
                entity_names.extend(extract_entity_names(child))
    return entity_names 

entity_names = []
for tree in chunked_sentences:
    entity_names.extend(extract_entity_names(tree))
    
print(set(entity_names))
# Out:
# {'Christmas', 'dbpedia_resourceItalian'}
